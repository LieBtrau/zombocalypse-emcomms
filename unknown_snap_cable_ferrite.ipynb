# %%
import skrf as rf
import math
import numpy
import matplotlib.pyplot as plt
from plotResults import plot_impedance, plot_vswr, plot_inductance

filepath = './measurements/unknown_snap_cable_ferrite/1-turn.s1p'

# nw_f1 = nw['0.50MHz-30MHz']
nw = rf.Network(filepath)
nw.name='Single turn'
nw_f1 = nw['0.55MHz-30MHz']
plot_vswr(nw_f1)
plot_impedance(filepath)
plot_inductance(filepath,'Single turn snap-ferrite')

filepath = './measurements/unknown_snap_cable_ferrite/1-turn_30MHz-1GHz.s1p'
nw = rf.Network(filepath)
plot_vswr(nw)
plot_impedance(filepath)
plot_inductance(filepath,'Single turn snap-ferrite')
